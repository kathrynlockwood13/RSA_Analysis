# %%
##importing packages
import nilearn as nil 
import pandas as pd 
import numpy as np 
import seaborn as sns 
import scipy.stats 
import nibabel as nib 
import os 
# %autosave 15
# Out:
# Autosaving every 15 seconds

# %%
##anterior hippocampus encoding 1, rest day 1
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-01.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-01_day1.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-01_day1_by_Trial-Run-01.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30

# %%
##2.anterior hippocampus encoding 1, rest day 2 rest 1 
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-01.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-01.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-01_day2_by_Trial-Run-01.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30

# %%
##3.anterior hippocampus encoding 1, rest day 2 rest 2 
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-01.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-02.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-02_day2_by_Trial-Run-01.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30

# %%
##4.anterior hippocampus encoding 2, rest day 1 rest 1
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-02.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-01_day1.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-01_day1_by_Trial-Run-02.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30

# %%
##5.anterior hippocampus encoding 2, rest day 2 rest 1
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-02.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-01.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-01_day2_by_Trial-Run-02.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30

# %%
##6.anterior hippocampus encoding 2, rest day 2 rest 1
import pandas as pd
import numpy as np
import os

# Loop through subjects '02' to '30'
for subject_num in range(2, 31):
    participant_str = f'{subject_num:02}'  # Format subject number with leading zero if needed

    # Read the CSV files into DataFrames
    df1 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXtrial_hipp_post_sub-{participant_str}_run-02.csv')
    df2 = pd.read_csv(f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/LSS_voxXTR_hipp_post_sub-{participant_str}_run-03.csv')

    # Drop the first column from df2
    df2 = df2.iloc[:, 1:]
    # Convert to numeric, ignoring errors
    df1 = df1.apply(pd.to_numeric, errors='coerce')
    df2 = df2.apply(pd.to_numeric, errors='coerce')

    # Concatenate the two dataframes along the columns (TRs first, then Trials)
    df = pd.concat([df2, df1], axis=1)

    # Compute the correlation matrix
    correlation_matrix = df.corr()

    # Determine the number of columns in each dataframe
    num_trial_columns = df1.shape[1]
    num_tr_columns = df2.shape[1]

    # Extract the portion of the correlation matrix corresponding to TR and Trial
    correlation_tr_trial = correlation_matrix.iloc[:num_tr_columns, num_tr_columns:]

    # Remove the 'Unnamed: 0' column
    correlation_tr_trial = correlation_tr_trial.drop(columns=['Unnamed: 0'])

    # Set row names to 'TR_01' through 'TR_210'
    correlation_tr_trial.index = [f'TR_{i:02}' for i in range(1, num_tr_columns + 1)]

    # Save correlation matrix as a CSV file with row names and column names
    output_folder = f'/data/Kathryn/Projects/Priority/derivatives/rsa_dfs/hipp_post/sub-{participant_str}/hipp_post_corr'
    output_filename = os.path.join(output_folder, f'corr_matrix_hipp_post_TR_Run-03_day2_by_Trial-Run-02.csv')
    correlation_tr_trial.to_csv(output_filename, index=True, header=True)

    print(f"Correlation matrix saved for Subject {participant_str}")
# Out:
# Correlation matrix saved for Subject 02
# Correlation matrix saved for Subject 03
# Correlation matrix saved for Subject 04
# Correlation matrix saved for Subject 05
# Correlation matrix saved for Subject 06
# Correlation matrix saved for Subject 07
# Correlation matrix saved for Subject 08
# Correlation matrix saved for Subject 09
# Correlation matrix saved for Subject 10
# Correlation matrix saved for Subject 11
# Correlation matrix saved for Subject 12
# Correlation matrix saved for Subject 13
# Correlation matrix saved for Subject 14
# Correlation matrix saved for Subject 15
# Correlation matrix saved for Subject 16
# Correlation matrix saved for Subject 17
# Correlation matrix saved for Subject 18
# Correlation matrix saved for Subject 19
# Correlation matrix saved for Subject 20
# Correlation matrix saved for Subject 21
# Correlation matrix saved for Subject 22
# Correlation matrix saved for Subject 23
# Correlation matrix saved for Subject 24
# Correlation matrix saved for Subject 25
# Correlation matrix saved for Subject 26
# Correlation matrix saved for Subject 27
# Correlation matrix saved for Subject 28
# Correlation matrix saved for Subject 29
# Correlation matrix saved for Subject 30
